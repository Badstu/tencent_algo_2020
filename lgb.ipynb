# %%
cd tencent_algo_2020/
# Out:
# [Errno 2] No such file or directory: 'tencent_algo_2020/'
# /home/sayhi/workspaces/tencent_algo_2020

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 

import data
import lightgbm as lgb
import numpy as np
import os
import sys
import re
import pandas as pd
import matplotlib
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.metrics import mean_squared_error, roc_auc_score, accuracy_score
from gensim.models import word2vec, keyedvectors
import logging

from model import lgb_model

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
print("START loading train embedding and train user info")
train_np = np.loadtxt("embed/train/ag_train_embedding_800_1.csv", delimiter=", ")
train_np[train_np == 0] = np.nan

# train_root = "dataset/train/"
# train_user_path = os.path.join(train_root, "user.csv")
# train_user = pd.read_csv(train_user_path, index_col="user_id")
print("FINISH load train_np, train_user")
print("===========================================================================")
# Out:
# START loading train embedding and train user info
# FINISH load train_np, train_user
# ===========================================================================

# %%
tc_train_age = pd.read_csv("tc/train_target_age.csv")
tc_train_gender = pd.read_csv("tc/train_target_gender.csv")

# %%
print("START get train_features, train_age, train_gender, and random split train/valid data")
uid = train_np[:, 0].astype(int)
train_age = train_np[:, -2].astype(int)
train_gender = train_np[:, -1].astype(int)

train_features = train_np[:, 1:-2]
train_features_gender = np.concatenate([train_features, tc_train_gender.values[:, 1:]], axis=1)
train_features_age = np.concatenate([train_features, tc_train_age.values[:, 1:]], axis=1)

train_age = train_age - 1
train_gender = train_gender - 1

train_features_gender, valid_features_gender,\
train_features_age, valid_features_age,\
train_age, valid_age,\
train_gender, valid_gender = train_test_split(train_features_gender,\
                                              train_features_age,\
                                              train_age,\
                                              train_gender,\
                                              test_size=0.33,\
                                              random_state=42)

print("FINISH random split train/valid data")
print("===========================================================================")

'''
train_age = train_user.loc[uid, "age"]
train_gender = train_user.loc[uid, "gender"]

train_features = train_np[:, 1:]
train_age = train_age.values - 1
train_gender = train_gender.values - 1

train_features, valid_features,\
train_age, valid_age,\
train_gender, valid_gender = train_test_split(train_features,\
                                              train_age,\
                                              train_gender,\
                                              test_size=0.33,\
                                              random_state=42)
print("FINISH random split train/valid data")
print("===========================================================================")
'''
# Out:
# START get train_features, train_age, train_gender, and random split train/valid data
# FINISH random split train/valid data
# ===========================================================================
# '\ntrain_age = train_user.loc[uid, "age"]\ntrain_gender = train_user.loc[uid, "gender"]\n\ntrain_features = train_np[:, 1:]\ntrain_age = train_age.values - 1\ntrain_gender = train_gender.values - 1\n\ntrain_features, valid_features,train_age, valid_age,train_gender, valid_gender = train_test_split(train_features,                                              train_age,                                              train_gender,                                              test_size=0.33,                                              random_state=42)\nprint("FINISH random split train/valid data")\nprint("===========================================================================")\n'

# %%
print("START construct lgb train valid data")
lgb_traindata_gender = lgb.Dataset(train_features_gender, train_gender)
lgb_traindata_age = lgb.Dataset(train_features_age, train_age)

lgb_valdata_gender = lgb.Dataset(valid_features_gender, valid_gender, reference=lgb_traindata_gender)
lgb_valdata_age = lgb.Dataset(valid_features_age, valid_age, reference=lgb_traindata_age)
print("FINISH construct lgb train valid data")
print("===========================================================================")
# Out:
# START construct lgb train valid data
# FINISH construct lgb train valid data
# ===========================================================================

# %%
print("START train model")
# TODO 性别模型的训练
gender_model = lgb_model(model_kind="gender")
gender_model.train(lgb_traindata_gender, lgb_valdata_gender)
gender_model.save_model("checkpoints/gender_model_complex.pkl")

# TODO 年龄模型的训练
age_model = lgb_model(model_kind="age")
age_model.train(lgb_traindata_age, lgb_valdata_age)
age_model.save_model("checkpoints/age_model_complex.pkl")
print("FINISH train model and save model")
print("===========================================================================")
# Out:
# START train model
# [1]	valid_0's auc: 0.966097	valid_0's binary_logloss: 0.564592
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's auc: 0.968195	valid_0's binary_logloss: 0.509656
# [3]	valid_0's auc: 0.970362	valid_0's binary_logloss: 0.464613
# [4]	valid_0's auc: 0.97084	valid_0's binary_logloss: 0.42722
# [5]	valid_0's auc: 0.971899	valid_0's binary_logloss: 0.395724
# [6]	valid_0's auc: 0.97211	valid_0's binary_logloss: 0.36948
# [7]	valid_0's auc: 0.972424	valid_0's binary_logloss: 0.346572
# [8]	valid_0's auc: 0.972831	valid_0's binary_logloss: 0.330346
# [9]	valid_0's auc: 0.973162	valid_0's binary_logloss: 0.312315
# [10]	valid_0's auc: 0.973808	valid_0's binary_logloss: 0.296511
# [11]	valid_0's auc: 0.974012	valid_0's binary_logloss: 0.282773
# [12]	valid_0's auc: 0.974464	valid_0's binary_logloss: 0.270771
# [13]	valid_0's auc: 0.974839	valid_0's binary_logloss: 0.260039
# [14]	valid_0's auc: 0.975039	valid_0's binary_logloss: 0.250573
# [15]	valid_0's auc: 0.975249	valid_0's binary_logloss: 0.242316
# [16]	valid_0's auc: 0.975493	valid_0's binary_logloss: 0.234827
# [17]	valid_0's auc: 0.975798	valid_0's binary_logloss: 0.228257
# [18]	valid_0's auc: 0.97629	valid_0's binary_logloss: 0.222276
# [19]	valid_0's auc: 0.976507	valid_0's binary_logloss: 0.216954
# [20]	valid_0's auc: 0.976646	valid_0's binary_logloss: 0.212421
# [21]	valid_0's auc: 0.976911	valid_0's binary_logloss: 0.208203
# [22]	valid_0's auc: 0.977142	valid_0's binary_logloss: 0.204318
# [23]	valid_0's auc: 0.977295	valid_0's binary_logloss: 0.200888
# [24]	valid_0's auc: 0.97746	valid_0's binary_logloss: 0.197819
# [25]	valid_0's auc: 0.977623	valid_0's binary_logloss: 0.194984
# [26]	valid_0's auc: 0.977747	valid_0's binary_logloss: 0.192488
# [27]	valid_0's auc: 0.977866	valid_0's binary_logloss: 0.190303
# [28]	valid_0's auc: 0.978021	valid_0's binary_logloss: 0.18819
# [29]	valid_0's auc: 0.97821	valid_0's binary_logloss: 0.186247
# [30]	valid_0's auc: 0.978342	valid_0's binary_logloss: 0.184546
# [31]	valid_0's auc: 0.978455	valid_0's binary_logloss: 0.18297
# [32]	valid_0's auc: 0.978582	valid_0's binary_logloss: 0.181569
# [33]	valid_0's auc: 0.978714	valid_0's binary_logloss: 0.180189
# [34]	valid_0's auc: 0.978855	valid_0's binary_logloss: 0.178813
# [35]	valid_0's auc: 0.978987	valid_0's binary_logloss: 0.177659
# [36]	valid_0's auc: 0.979085	valid_0's binary_logloss: 0.176682
# [37]	valid_0's auc: 0.979185	valid_0's binary_logloss: 0.175704
# [38]	valid_0's auc: 0.979301	valid_0's binary_logloss: 0.17467
# [39]	valid_0's auc: 0.979411	valid_0's binary_logloss: 0.173804
# [40]	valid_0's auc: 0.979504	valid_0's binary_logloss: 0.173021
# [41]	valid_0's auc: 0.979631	valid_0's binary_logloss: 0.172201
# [42]	valid_0's auc: 0.979734	valid_0's binary_logloss: 0.171497
# [43]	valid_0's auc: 0.979826	valid_0's binary_logloss: 0.170836
# [44]	valid_0's auc: 0.9799	valid_0's binary_logloss: 0.170274
# [45]	valid_0's auc: 0.980018	valid_0's binary_logloss: 0.169647
# [46]	valid_0's auc: 0.980084	valid_0's binary_logloss: 0.169139
# [47]	valid_0's auc: 0.980181	valid_0's binary_logloss: 0.168623
# [48]	valid_0's auc: 0.980274	valid_0's binary_logloss: 0.168112
# [49]	valid_0's auc: 0.980363	valid_0's binary_logloss: 0.167602
# [50]	valid_0's auc: 0.980442	valid_0's binary_logloss: 0.167121
# [51]	valid_0's auc: 0.980494	valid_0's binary_logloss: 0.166762
# [52]	valid_0's auc: 0.980578	valid_0's binary_logloss: 0.166314
# [53]	valid_0's auc: 0.980638	valid_0's binary_logloss: 0.165935
# [54]	valid_0's auc: 0.98072	valid_0's binary_logloss: 0.16548
# [55]	valid_0's auc: 0.980772	valid_0's binary_logloss: 0.165153
# [56]	valid_0's auc: 0.98085	valid_0's binary_logloss: 0.164757
# [57]	valid_0's auc: 0.9809	valid_0's binary_logloss: 0.164475
# [58]	valid_0's auc: 0.980975	valid_0's binary_logloss: 0.16411
# [59]	valid_0's auc: 0.981029	valid_0's binary_logloss: 0.163806
# [60]	valid_0's auc: 0.981076	valid_0's binary_logloss: 0.163527
# [61]	valid_0's auc: 0.981134	valid_0's binary_logloss: 0.163213
# [62]	valid_0's auc: 0.981193	valid_0's binary_logloss: 0.162939
# [63]	valid_0's auc: 0.981234	valid_0's binary_logloss: 0.162701
# [64]	valid_0's auc: 0.981269	valid_0's binary_logloss: 0.1625
# [65]	valid_0's auc: 0.981319	valid_0's binary_logloss: 0.162262
# [66]	valid_0's auc: 0.981357	valid_0's binary_logloss: 0.16207
# [67]	valid_0's auc: 0.981397	valid_0's binary_logloss: 0.161841
# [68]	valid_0's auc: 0.981444	valid_0's binary_logloss: 0.161592
# [69]	valid_0's auc: 0.981482	valid_0's binary_logloss: 0.161384
# [70]	valid_0's auc: 0.981518	valid_0's binary_logloss: 0.161196
# [71]	valid_0's auc: 0.981563	valid_0's binary_logloss: 0.160982
# [72]	valid_0's auc: 0.981599	valid_0's binary_logloss: 0.160794
# [73]	valid_0's auc: 0.981629	valid_0's binary_logloss: 0.160614
# [74]	valid_0's auc: 0.981661	valid_0's binary_logloss: 0.160439
# [75]	valid_0's auc: 0.981694	valid_0's binary_logloss: 0.160247
# [76]	valid_0's auc: 0.981728	valid_0's binary_logloss: 0.160074
# [77]	valid_0's auc: 0.981755	valid_0's binary_logloss: 0.159933
# [78]	valid_0's auc: 0.9818	valid_0's binary_logloss: 0.159693
# [79]	valid_0's auc: 0.981828	valid_0's binary_logloss: 0.15953
# [80]	valid_0's auc: 0.981879	valid_0's binary_logloss: 0.159275
# [81]	valid_0's auc: 0.981917	valid_0's binary_logloss: 0.159076
# [82]	valid_0's auc: 0.981957	valid_0's binary_logloss: 0.1589
# [83]	valid_0's auc: 0.981977	valid_0's binary_logloss: 0.158771
# [84]	valid_0's auc: 0.982015	valid_0's binary_logloss: 0.158593
# [85]	valid_0's auc: 0.982043	valid_0's binary_logloss: 0.158466
# [86]	valid_0's auc: 0.982064	valid_0's binary_logloss: 0.158341
# [87]	valid_0's auc: 0.982115	valid_0's binary_logloss: 0.158092
# [88]	valid_0's auc: 0.982144	valid_0's binary_logloss: 0.157926
# [89]	valid_0's auc: 0.982175	valid_0's binary_logloss: 0.157772
# [90]	valid_0's auc: 0.982201	valid_0's binary_logloss: 0.157638
# [91]	valid_0's auc: 0.982223	valid_0's binary_logloss: 0.157518
# [92]	valid_0's auc: 0.982252	valid_0's binary_logloss: 0.157379
# [93]	valid_0's auc: 0.982274	valid_0's binary_logloss: 0.157262
# [94]	valid_0's auc: 0.982306	valid_0's binary_logloss: 0.157114
# [95]	valid_0's auc: 0.982337	valid_0's binary_logloss: 0.156968
# [96]	valid_0's auc: 0.982374	valid_0's binary_logloss: 0.156802
# [97]	valid_0's auc: 0.982392	valid_0's binary_logloss: 0.156699
# [98]	valid_0's auc: 0.982421	valid_0's binary_logloss: 0.156573
# [99]	valid_0's auc: 0.982437	valid_0's binary_logloss: 0.156482
# [100]	valid_0's auc: 0.982458	valid_0's binary_logloss: 0.156374
# [101]	valid_0's auc: 0.98248	valid_0's binary_logloss: 0.156275
# [102]	valid_0's auc: 0.982496	valid_0's binary_logloss: 0.156177
# [103]	valid_0's auc: 0.98252	valid_0's binary_logloss: 0.156047
# [104]	valid_0's auc: 0.982541	valid_0's binary_logloss: 0.155943
# [105]	valid_0's auc: 0.982561	valid_0's binary_logloss: 0.155828
# [106]	valid_0's auc: 0.982573	valid_0's binary_logloss: 0.155749
# [107]	valid_0's auc: 0.982586	valid_0's binary_logloss: 0.155665
# [108]	valid_0's auc: 0.982619	valid_0's binary_logloss: 0.155511
# [109]	valid_0's auc: 0.982651	valid_0's binary_logloss: 0.155357
# [110]	valid_0's auc: 0.982676	valid_0's binary_logloss: 0.155232
# [111]	valid_0's auc: 0.98271	valid_0's binary_logloss: 0.155071
# [112]	valid_0's auc: 0.982729	valid_0's binary_logloss: 0.154956
# [113]	valid_0's auc: 0.982746	valid_0's binary_logloss: 0.154871
# [114]	valid_0's auc: 0.982762	valid_0's binary_logloss: 0.154784
# [115]	valid_0's auc: 0.982778	valid_0's binary_logloss: 0.154686
# [116]	valid_0's auc: 0.982799	valid_0's binary_logloss: 0.154583
# [117]	valid_0's auc: 0.982815	valid_0's binary_logloss: 0.154491
# [118]	valid_0's auc: 0.982843	valid_0's binary_logloss: 0.154357
# [119]	valid_0's auc: 0.982858	valid_0's binary_logloss: 0.154271
# [120]	valid_0's auc: 0.982878	valid_0's binary_logloss: 0.15417
# [121]	valid_0's auc: 0.982895	valid_0's binary_logloss: 0.154093
# [122]	valid_0's auc: 0.982915	valid_0's binary_logloss: 0.153987
# [123]	valid_0's auc: 0.982936	valid_0's binary_logloss: 0.153878
# [124]	valid_0's auc: 0.98295	valid_0's binary_logloss: 0.153798
# [125]	valid_0's auc: 0.982959	valid_0's binary_logloss: 0.153733
# [126]	valid_0's auc: 0.98298	valid_0's binary_logloss: 0.153638
# [127]	valid_0's auc: 0.982999	valid_0's binary_logloss: 0.153546
# [128]	valid_0's auc: 0.983008	valid_0's binary_logloss: 0.153502
# [129]	valid_0's auc: 0.983021	valid_0's binary_logloss: 0.153433
# [130]	valid_0's auc: 0.983034	valid_0's binary_logloss: 0.15335
# [131]	valid_0's auc: 0.983039	valid_0's binary_logloss: 0.153313
# [132]	valid_0's auc: 0.98305	valid_0's binary_logloss: 0.15326
# [133]	valid_0's auc: 0.983058	valid_0's binary_logloss: 0.153213
# [134]	valid_0's auc: 0.983071	valid_0's binary_logloss: 0.153144
# [135]	valid_0's auc: 0.983083	valid_0's binary_logloss: 0.153074
# [136]	valid_0's auc: 0.983096	valid_0's binary_logloss: 0.153013
# [137]	valid_0's auc: 0.983121	valid_0's binary_logloss: 0.152913
# [138]	valid_0's auc: 0.983137	valid_0's binary_logloss: 0.152831
# [139]	valid_0's auc: 0.983158	valid_0's binary_logloss: 0.152731
# [140]	valid_0's auc: 0.983176	valid_0's binary_logloss: 0.152649
# [141]	valid_0's auc: 0.983187	valid_0's binary_logloss: 0.152592
# [142]	valid_0's auc: 0.983194	valid_0's binary_logloss: 0.152548
# [143]	valid_0's auc: 0.98322	valid_0's binary_logloss: 0.152437
# [144]	valid_0's auc: 0.983234	valid_0's binary_logloss: 0.152368
# [145]	valid_0's auc: 0.983243	valid_0's binary_logloss: 0.152314
# [146]	valid_0's auc: 0.983252	valid_0's binary_logloss: 0.15226
# [147]	valid_0's auc: 0.983264	valid_0's binary_logloss: 0.15219
# [148]	valid_0's auc: 0.98328	valid_0's binary_logloss: 0.152108
# [149]	valid_0's auc: 0.983288	valid_0's binary_logloss: 0.152065
# [150]	valid_0's auc: 0.983304	valid_0's binary_logloss: 0.151991
# [151]	valid_0's auc: 0.983313	valid_0's binary_logloss: 0.151941
# [152]	valid_0's auc: 0.983319	valid_0's binary_logloss: 0.151902
# [153]	valid_0's auc: 0.983333	valid_0's binary_logloss: 0.151841
# [154]	valid_0's auc: 0.98335	valid_0's binary_logloss: 0.151751
# [155]	valid_0's auc: 0.983369	valid_0's binary_logloss: 0.151669
# [156]	valid_0's auc: 0.983381	valid_0's binary_logloss: 0.151611
# [157]	valid_0's auc: 0.983388	valid_0's binary_logloss: 0.151564
# [158]	valid_0's auc: 0.983399	valid_0's binary_logloss: 0.151503
# [159]	valid_0's auc: 0.983409	valid_0's binary_logloss: 0.151459
# [160]	valid_0's auc: 0.983418	valid_0's binary_logloss: 0.151424
# [161]	valid_0's auc: 0.983425	valid_0's binary_logloss: 0.151372
# [162]	valid_0's auc: 0.983436	valid_0's binary_logloss: 0.151322
# [163]	valid_0's auc: 0.983449	valid_0's binary_logloss: 0.151257
# [164]	valid_0's auc: 0.983457	valid_0's binary_logloss: 0.151201
# [165]	valid_0's auc: 0.983463	valid_0's binary_logloss: 0.151158
# [166]	valid_0's auc: 0.983471	valid_0's binary_logloss: 0.15112
# [167]	valid_0's auc: 0.983484	valid_0's binary_logloss: 0.151065
# [168]	valid_0's auc: 0.983486	valid_0's binary_logloss: 0.151044
# [169]	valid_0's auc: 0.983487	valid_0's binary_logloss: 0.151026
# [170]	valid_0's auc: 0.983505	valid_0's binary_logloss: 0.150944
# [171]	valid_0's auc: 0.983513	valid_0's binary_logloss: 0.150902
# [172]	valid_0's auc: 0.983527	valid_0's binary_logloss: 0.150833
# [173]	valid_0's auc: 0.983536	valid_0's binary_logloss: 0.150781
# [174]	valid_0's auc: 0.983568	valid_0's binary_logloss: 0.150628
# [175]	valid_0's auc: 0.983584	valid_0's binary_logloss: 0.150567
# [176]	valid_0's auc: 0.983589	valid_0's binary_logloss: 0.15053
# [177]	valid_0's auc: 0.9836	valid_0's binary_logloss: 0.150477
# [178]	valid_0's auc: 0.983607	valid_0's binary_logloss: 0.150436
# [179]	valid_0's auc: 0.983615	valid_0's binary_logloss: 0.150387
# [180]	valid_0's auc: 0.983618	valid_0's binary_logloss: 0.150363
# [181]	valid_0's auc: 0.983626	valid_0's binary_logloss: 0.150323
# [182]	valid_0's auc: 0.98363	valid_0's binary_logloss: 0.1503
# [183]	valid_0's auc: 0.98364	valid_0's binary_logloss: 0.15026
# [184]	valid_0's auc: 0.983649	valid_0's binary_logloss: 0.150207
# [185]	valid_0's auc: 0.983656	valid_0's binary_logloss: 0.15018
# [186]	valid_0's auc: 0.983665	valid_0's binary_logloss: 0.150125
# [187]	valid_0's auc: 0.983668	valid_0's binary_logloss: 0.150101
# [188]	valid_0's auc: 0.983689	valid_0's binary_logloss: 0.149999
# [189]	valid_0's auc: 0.983698	valid_0's binary_logloss: 0.149953
# [190]	valid_0's auc: 0.983702	valid_0's binary_logloss: 0.149933
# [191]	valid_0's auc: 0.983706	valid_0's binary_logloss: 0.149906
# [192]	valid_0's auc: 0.983711	valid_0's binary_logloss: 0.14988
# [193]	valid_0's auc: 0.983723	valid_0's binary_logloss: 0.149824
# [194]	valid_0's auc: 0.983732	valid_0's binary_logloss: 0.149775
# [195]	valid_0's auc: 0.983736	valid_0's binary_logloss: 0.149753
# [196]	valid_0's auc: 0.983743	valid_0's binary_logloss: 0.14972
# [197]	valid_0's auc: 0.983754	valid_0's binary_logloss: 0.149662
# [198]	valid_0's auc: 0.983762	valid_0's binary_logloss: 0.14962
# [199]	valid_0's auc: 0.98377	valid_0's binary_logloss: 0.149573
# [200]	valid_0's auc: 0.983778	valid_0's binary_logloss: 0.149535
# Did not meet early stopping. Best iteration is:
# [200]	valid_0's auc: 0.983778	valid_0's binary_logloss: 0.149535
# [1]	valid_0's multi_logloss: 1.99592
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 1.9675
# [3]	valid_0's multi_logloss: 1.9431
# [4]	valid_0's multi_logloss: 1.92166
# [5]	valid_0's multi_logloss: 1.9022
# [6]	valid_0's multi_logloss: 1.88458
# [7]	valid_0's multi_logloss: 1.86858
# [8]	valid_0's multi_logloss: 1.85401
# [9]	valid_0's multi_logloss: 1.84036
# [10]	valid_0's multi_logloss: 1.82776
# [11]	valid_0's multi_logloss: 1.8162
# [12]	valid_0's multi_logloss: 1.80524
# [13]	valid_0's multi_logloss: 1.79506
# [14]	valid_0's multi_logloss: 1.78537
# [15]	valid_0's multi_logloss: 1.77655
# [16]	valid_0's multi_logloss: 1.76826
# [17]	valid_0's multi_logloss: 1.7605
# [18]	valid_0's multi_logloss: 1.75324
# [19]	valid_0's multi_logloss: 1.74642
# [20]	valid_0's multi_logloss: 1.73977
# [21]	valid_0's multi_logloss: 1.7333
# [22]	valid_0's multi_logloss: 1.72737
# [23]	valid_0's multi_logloss: 1.72163
# [24]	valid_0's multi_logloss: 1.71625
# [25]	valid_0's multi_logloss: 1.71112
# [26]	valid_0's multi_logloss: 1.7062
# [27]	valid_0's multi_logloss: 1.70154
# [28]	valid_0's multi_logloss: 1.69706
# [29]	valid_0's multi_logloss: 1.69261
# [30]	valid_0's multi_logloss: 1.68856
# [31]	valid_0's multi_logloss: 1.68447
# [32]	valid_0's multi_logloss: 1.68068
# [33]	valid_0's multi_logloss: 1.67709
# [34]	valid_0's multi_logloss: 1.67367
# [35]	valid_0's multi_logloss: 1.67029
# [36]	valid_0's multi_logloss: 1.66702
# [37]	valid_0's multi_logloss: 1.66401
# [38]	valid_0's multi_logloss: 1.66105
# [39]	valid_0's multi_logloss: 1.65823
# [40]	valid_0's multi_logloss: 1.65547
# [41]	valid_0's multi_logloss: 1.65284
# [42]	valid_0's multi_logloss: 1.65028
# [43]	valid_0's multi_logloss: 1.64781
# [44]	valid_0's multi_logloss: 1.64542
# [45]	valid_0's multi_logloss: 1.64318
# [46]	valid_0's multi_logloss: 1.64093
# [47]	valid_0's multi_logloss: 1.63888
# [48]	valid_0's multi_logloss: 1.63682
# [49]	valid_0's multi_logloss: 1.63472
# [50]	valid_0's multi_logloss: 1.63283
# [51]	valid_0's multi_logloss: 1.63089
# [52]	valid_0's multi_logloss: 1.62913
# [53]	valid_0's multi_logloss: 1.62734
# [54]	valid_0's multi_logloss: 1.6255
# [55]	valid_0's multi_logloss: 1.62381
# [56]	valid_0's multi_logloss: 1.62214
# [57]	valid_0's multi_logloss: 1.62055
# [58]	valid_0's multi_logloss: 1.61904
# [59]	valid_0's multi_logloss: 1.61758
# [60]	valid_0's multi_logloss: 1.61607
# [61]	valid_0's multi_logloss: 1.61461
# [62]	valid_0's multi_logloss: 1.61324
# [63]	valid_0's multi_logloss: 1.6119
# [64]	valid_0's multi_logloss: 1.61056
# [65]	valid_0's multi_logloss: 1.60919
# [66]	valid_0's multi_logloss: 1.60793
# [67]	valid_0's multi_logloss: 1.60666
# [68]	valid_0's multi_logloss: 1.60553
# [69]	valid_0's multi_logloss: 1.6044
# [70]	valid_0's multi_logloss: 1.60324
# [71]	valid_0's multi_logloss: 1.60211
# [72]	valid_0's multi_logloss: 1.601
# [73]	valid_0's multi_logloss: 1.59995
# [74]	valid_0's multi_logloss: 1.59889
# [75]	valid_0's multi_logloss: 1.59781
# [76]	valid_0's multi_logloss: 1.59678
# [77]	valid_0's multi_logloss: 1.59574
# [78]	valid_0's multi_logloss: 1.59471
# [79]	valid_0's multi_logloss: 1.59379
# [80]	valid_0's multi_logloss: 1.59284
# [81]	valid_0's multi_logloss: 1.59195
# [82]	valid_0's multi_logloss: 1.59107
# [83]	valid_0's multi_logloss: 1.59015
# [84]	valid_0's multi_logloss: 1.58931
# [85]	valid_0's multi_logloss: 1.58842
# [86]	valid_0's multi_logloss: 1.58763
# [87]	valid_0's multi_logloss: 1.5868
# [88]	valid_0's multi_logloss: 1.58603
# [89]	valid_0's multi_logloss: 1.58531
# [90]	valid_0's multi_logloss: 1.58456
# [91]	valid_0's multi_logloss: 1.58383
# [92]	valid_0's multi_logloss: 1.58301
# [93]	valid_0's multi_logloss: 1.58229
# [94]	valid_0's multi_logloss: 1.58156
# [95]	valid_0's multi_logloss: 1.58085
# [96]	valid_0's multi_logloss: 1.58017
# [97]	valid_0's multi_logloss: 1.57951
# [98]	valid_0's multi_logloss: 1.5789
# [99]	valid_0's multi_logloss: 1.57823
# [100]	valid_0's multi_logloss: 1.57761
# [101]	valid_0's multi_logloss: 1.57697
# [102]	valid_0's multi_logloss: 1.57636
# [103]	valid_0's multi_logloss: 1.57575
# [104]	valid_0's multi_logloss: 1.57514
# [105]	valid_0's multi_logloss: 1.57458
# [106]	valid_0's multi_logloss: 1.574
# [107]	valid_0's multi_logloss: 1.57346
# [108]	valid_0's multi_logloss: 1.57292
# [109]	valid_0's multi_logloss: 1.57235
# [110]	valid_0's multi_logloss: 1.57174
# [111]	valid_0's multi_logloss: 1.57124
# [112]	valid_0's multi_logloss: 1.5707
# [113]	valid_0's multi_logloss: 1.57021
# [114]	valid_0's multi_logloss: 1.56969
# [115]	valid_0's multi_logloss: 1.56917
# [116]	valid_0's multi_logloss: 1.56865
# [117]	valid_0's multi_logloss: 1.56818
# [118]	valid_0's multi_logloss: 1.56773
# [119]	valid_0's multi_logloss: 1.56724
# [120]	valid_0's multi_logloss: 1.56679
# [121]	valid_0's multi_logloss: 1.56633
# [122]	valid_0's multi_logloss: 1.56585
# [123]	valid_0's multi_logloss: 1.56538
# [124]	valid_0's multi_logloss: 1.56492
# [125]	valid_0's multi_logloss: 1.56449
# [126]	valid_0's multi_logloss: 1.56401
# [127]	valid_0's multi_logloss: 1.5635
# [128]	valid_0's multi_logloss: 1.56306
# [129]	valid_0's multi_logloss: 1.5626
# [130]	valid_0's multi_logloss: 1.56217
# [131]	valid_0's multi_logloss: 1.56172
# [132]	valid_0's multi_logloss: 1.56132
# [133]	valid_0's multi_logloss: 1.56098
# [134]	valid_0's multi_logloss: 1.5606
# [135]	valid_0's multi_logloss: 1.56022
# [136]	valid_0's multi_logloss: 1.55986
# [137]	valid_0's multi_logloss: 1.55949
# [138]	valid_0's multi_logloss: 1.55914
# [139]	valid_0's multi_logloss: 1.55877
# [140]	valid_0's multi_logloss: 1.55841
# [141]	valid_0's multi_logloss: 1.55799
# [142]	valid_0's multi_logloss: 1.5576
# [143]	valid_0's multi_logloss: 1.55728
# [144]	valid_0's multi_logloss: 1.55692
# [145]	valid_0's multi_logloss: 1.55658
# [146]	valid_0's multi_logloss: 1.55625
# [147]	valid_0's multi_logloss: 1.55589
# [148]	valid_0's multi_logloss: 1.55554
# [149]	valid_0's multi_logloss: 1.55525
# [150]	valid_0's multi_logloss: 1.5549
# [151]	valid_0's multi_logloss: 1.55454
# [152]	valid_0's multi_logloss: 1.55421
# [153]	valid_0's multi_logloss: 1.55389
# [154]	valid_0's multi_logloss: 1.55359
# [155]	valid_0's multi_logloss: 1.55329
# [156]	valid_0's multi_logloss: 1.553
# [157]	valid_0's multi_logloss: 1.55269
# [158]	valid_0's multi_logloss: 1.55239
# [159]	valid_0's multi_logloss: 1.55211
# [160]	valid_0's multi_logloss: 1.55184
# [161]	valid_0's multi_logloss: 1.55155
# [162]	valid_0's multi_logloss: 1.55124
# [163]	valid_0's multi_logloss: 1.55096
# [164]	valid_0's multi_logloss: 1.55069
# [165]	valid_0's multi_logloss: 1.55041
# [166]	valid_0's multi_logloss: 1.55012
# [167]	valid_0's multi_logloss: 1.54983
# [168]	valid_0's multi_logloss: 1.54956
# [169]	valid_0's multi_logloss: 1.5493
# [170]	valid_0's multi_logloss: 1.54909
# [171]	valid_0's multi_logloss: 1.54878
# [172]	valid_0's multi_logloss: 1.54852
# [173]	valid_0's multi_logloss: 1.54823
# [174]	valid_0's multi_logloss: 1.54797
# [175]	valid_0's multi_logloss: 1.54772
# [176]	valid_0's multi_logloss: 1.54745
# [177]	valid_0's multi_logloss: 1.5472
# [178]	valid_0's multi_logloss: 1.54692
# [179]	valid_0's multi_logloss: 1.54667
# [180]	valid_0's multi_logloss: 1.54643
# [181]	valid_0's multi_logloss: 1.54617
# [182]	valid_0's multi_logloss: 1.54592
# [183]	valid_0's multi_logloss: 1.5457
# [184]	valid_0's multi_logloss: 1.54549
# [185]	valid_0's multi_logloss: 1.54527
# [186]	valid_0's multi_logloss: 1.54503
# [187]	valid_0's multi_logloss: 1.54483
# [188]	valid_0's multi_logloss: 1.54464
# [189]	valid_0's multi_logloss: 1.54439
# [190]	valid_0's multi_logloss: 1.54418
# [191]	valid_0's multi_logloss: 1.54395
# [192]	valid_0's multi_logloss: 1.54373
# [193]	valid_0's multi_logloss: 1.54352
# [194]	valid_0's multi_logloss: 1.54331
# [195]	valid_0's multi_logloss: 1.54307
# [196]	valid_0's multi_logloss: 1.54288
# [197]	valid_0's multi_logloss: 1.54263
# [198]	valid_0's multi_logloss: 1.54242
# [199]	valid_0's multi_logloss: 1.54221
# [200]	valid_0's multi_logloss: 1.54201
# [201]	valid_0's multi_logloss: 1.54182
# [202]	valid_0's multi_logloss: 1.54162
# [203]	valid_0's multi_logloss: 1.54142
# [204]	valid_0's multi_logloss: 1.54122
# [205]	valid_0's multi_logloss: 1.54105
# [206]	valid_0's multi_logloss: 1.54085
# [207]	valid_0's multi_logloss: 1.54066
# [208]	valid_0's multi_logloss: 1.54048
# [209]	valid_0's multi_logloss: 1.54034
# [210]	valid_0's multi_logloss: 1.54016
# [211]	valid_0's multi_logloss: 1.53997
# [212]	valid_0's multi_logloss: 1.5398
# [213]	valid_0's multi_logloss: 1.53961
# [214]	valid_0's multi_logloss: 1.53944
# [215]	valid_0's multi_logloss: 1.53924
# [216]	valid_0's multi_logloss: 1.53906
# [217]	valid_0's multi_logloss: 1.53889
# [218]	valid_0's multi_logloss: 1.5387
# [219]	valid_0's multi_logloss: 1.53852
# [220]	valid_0's multi_logloss: 1.53837
# [221]	valid_0's multi_logloss: 1.53818
# [222]	valid_0's multi_logloss: 1.53801
# [223]	valid_0's multi_logloss: 1.53783
# [224]	valid_0's multi_logloss: 1.53768
# [225]	valid_0's multi_logloss: 1.53753
# [226]	valid_0's multi_logloss: 1.53737
# [227]	valid_0's multi_logloss: 1.53722
# [228]	valid_0's multi_logloss: 1.53704
# [229]	valid_0's multi_logloss: 1.53689
# [230]	valid_0's multi_logloss: 1.53672
# [231]	valid_0's multi_logloss: 1.53655
# [232]	valid_0's multi_logloss: 1.53641
# [233]	valid_0's multi_logloss: 1.53629
# [234]	valid_0's multi_logloss: 1.53613
# [235]	valid_0's multi_logloss: 1.53596
# [236]	valid_0's multi_logloss: 1.5358
# [237]	valid_0's multi_logloss: 1.53569
# [238]	valid_0's multi_logloss: 1.53556
# [239]	valid_0's multi_logloss: 1.5354
# [240]	valid_0's multi_logloss: 1.53527
# [241]	valid_0's multi_logloss: 1.53511
# [242]	valid_0's multi_logloss: 1.535
# [243]	valid_0's multi_logloss: 1.53486
# [244]	valid_0's multi_logloss: 1.53473
# [245]	valid_0's multi_logloss: 1.53462
# [246]	valid_0's multi_logloss: 1.5345
# [247]	valid_0's multi_logloss: 1.53438
# [248]	valid_0's multi_logloss: 1.53425
# [249]	valid_0's multi_logloss: 1.53412
# [250]	valid_0's multi_logloss: 1.53398
# [251]	valid_0's multi_logloss: 1.53384
# [252]	valid_0's multi_logloss: 1.53372
# [253]	valid_0's multi_logloss: 1.5336
# [254]	valid_0's multi_logloss: 1.5335
# [255]	valid_0's multi_logloss: 1.53338
# [256]	valid_0's multi_logloss: 1.5332
# [257]	valid_0's multi_logloss: 1.53308
# [258]	valid_0's multi_logloss: 1.53294
# [259]	valid_0's multi_logloss: 1.53282
# [260]	valid_0's multi_logloss: 1.5327
# [261]	valid_0's multi_logloss: 1.53258
# [262]	valid_0's multi_logloss: 1.53247
# [263]	valid_0's multi_logloss: 1.53233
# [264]	valid_0's multi_logloss: 1.53221
# [265]	valid_0's multi_logloss: 1.53209
# [266]	valid_0's multi_logloss: 1.532
# [267]	valid_0's multi_logloss: 1.53189
# [268]	valid_0's multi_logloss: 1.53174
# [269]	valid_0's multi_logloss: 1.53163
# [270]	valid_0's multi_logloss: 1.5315
# [271]	valid_0's multi_logloss: 1.5314
# [272]	valid_0's multi_logloss: 1.5313
# [273]	valid_0's multi_logloss: 1.5312
# [274]	valid_0's multi_logloss: 1.53108
# [275]	valid_0's multi_logloss: 1.53096
# [276]	valid_0's multi_logloss: 1.53083
# [277]	valid_0's multi_logloss: 1.53074
# [278]	valid_0's multi_logloss: 1.53061
# [279]	valid_0's multi_logloss: 1.53049
# [280]	valid_0's multi_logloss: 1.53038
# [281]	valid_0's multi_logloss: 1.5303
# [282]	valid_0's multi_logloss: 1.53021
# [283]	valid_0's multi_logloss: 1.53008
# [284]	valid_0's multi_logloss: 1.52999
# [285]	valid_0's multi_logloss: 1.52991
# [286]	valid_0's multi_logloss: 1.52982
# [287]	valid_0's multi_logloss: 1.52969
# [288]	valid_0's multi_logloss: 1.52957
# [289]	valid_0's multi_logloss: 1.52944
# [290]	valid_0's multi_logloss: 1.52938
# [291]	valid_0's multi_logloss: 1.52924
# [292]	valid_0's multi_logloss: 1.52913
# [293]	valid_0's multi_logloss: 1.52902
# [294]	valid_0's multi_logloss: 1.52895
# [295]	valid_0's multi_logloss: 1.52886
# [296]	valid_0's multi_logloss: 1.52876
# [297]	valid_0's multi_logloss: 1.52865
# [298]	valid_0's multi_logloss: 1.52855
# [299]	valid_0's multi_logloss: 1.52845
# [300]	valid_0's multi_logloss: 1.52834
# [301]	valid_0's multi_logloss: 1.52824
# [302]	valid_0's multi_logloss: 1.52815
# [303]	valid_0's multi_logloss: 1.52809
# [304]	valid_0's multi_logloss: 1.52798
# [305]	valid_0's multi_logloss: 1.5279
# [306]	valid_0's multi_logloss: 1.52783
# [307]	valid_0's multi_logloss: 1.52776
# [308]	valid_0's multi_logloss: 1.52765
# [309]	valid_0's multi_logloss: 1.52761
# [310]	valid_0's multi_logloss: 1.52752
# [311]	valid_0's multi_logloss: 1.52742
# [312]	valid_0's multi_logloss: 1.52734
# [313]	valid_0's multi_logloss: 1.52728
# [314]	valid_0's multi_logloss: 1.52717
# [315]	valid_0's multi_logloss: 1.52707
# [316]	valid_0's multi_logloss: 1.52698
# [317]	valid_0's multi_logloss: 1.52691
# [318]	valid_0's multi_logloss: 1.52683
# [319]	valid_0's multi_logloss: 1.52675
# [320]	valid_0's multi_logloss: 1.52667
# [321]	valid_0's multi_logloss: 1.52662
# [322]	valid_0's multi_logloss: 1.52653
# [323]	valid_0's multi_logloss: 1.52649
# [324]	valid_0's multi_logloss: 1.52643
# [325]	valid_0's multi_logloss: 1.52633
# [326]	valid_0's multi_logloss: 1.52627
# [327]	valid_0's multi_logloss: 1.52618
# [328]	valid_0's multi_logloss: 1.52611
# [329]	valid_0's multi_logloss: 1.52602
# [330]	valid_0's multi_logloss: 1.52593
# [331]	valid_0's multi_logloss: 1.52585
# [332]	valid_0's multi_logloss: 1.52576
# [333]	valid_0's multi_logloss: 1.52569
# [334]	valid_0's multi_logloss: 1.52563
# [335]	valid_0's multi_logloss: 1.52557
# [336]	valid_0's multi_logloss: 1.52548
# [337]	valid_0's multi_logloss: 1.5254
# [338]	valid_0's multi_logloss: 1.52536
# [339]	valid_0's multi_logloss: 1.52531
# [340]	valid_0's multi_logloss: 1.52525
# [341]	valid_0's multi_logloss: 1.52517
# [342]	valid_0's multi_logloss: 1.52509
# [343]	valid_0's multi_logloss: 1.52501
# [344]	valid_0's multi_logloss: 1.52496
# [345]	valid_0's multi_logloss: 1.52489
# [346]	valid_0's multi_logloss: 1.52483
# [347]	valid_0's multi_logloss: 1.52475
# [348]	valid_0's multi_logloss: 1.52466
# [349]	valid_0's multi_logloss: 1.5246
# [350]	valid_0's multi_logloss: 1.52454
# [351]	valid_0's multi_logloss: 1.52449
# [352]	valid_0's multi_logloss: 1.52445
# [353]	valid_0's multi_logloss: 1.52439
# [354]	valid_0's multi_logloss: 1.52431
# [355]	valid_0's multi_logloss: 1.52424
# [356]	valid_0's multi_logloss: 1.52414
# [357]	valid_0's multi_logloss: 1.52412
# [358]	valid_0's multi_logloss: 1.52406
# [359]	valid_0's multi_logloss: 1.52399
# [360]	valid_0's multi_logloss: 1.52394
# [361]	valid_0's multi_logloss: 1.5239
# [362]	valid_0's multi_logloss: 1.52385
# [363]	valid_0's multi_logloss: 1.52378
# [364]	valid_0's multi_logloss: 1.52374
# [365]	valid_0's multi_logloss: 1.52369
# [366]	valid_0's multi_logloss: 1.52364
# [367]	valid_0's multi_logloss: 1.52358
# [368]	valid_0's multi_logloss: 1.52353
# [369]	valid_0's multi_logloss: 1.52349
# [370]	valid_0's multi_logloss: 1.52344
# [371]	valid_0's multi_logloss: 1.52339
# [372]	valid_0's multi_logloss: 1.52334
# [373]	valid_0's multi_logloss: 1.52329
# [374]	valid_0's multi_logloss: 1.52325
# [375]	valid_0's multi_logloss: 1.52321
# [376]	valid_0's multi_logloss: 1.52317
# [377]	valid_0's multi_logloss: 1.52313
# [378]	valid_0's multi_logloss: 1.52307
# [379]	valid_0's multi_logloss: 1.523
# [380]	valid_0's multi_logloss: 1.52293
# [381]	valid_0's multi_logloss: 1.52289
# [382]	valid_0's multi_logloss: 1.52282
# [383]	valid_0's multi_logloss: 1.52276
# [384]	valid_0's multi_logloss: 1.52271
# [385]	valid_0's multi_logloss: 1.52269
# [386]	valid_0's multi_logloss: 1.52263
# [387]	valid_0's multi_logloss: 1.52258
# [388]	valid_0's multi_logloss: 1.52254
# [389]	valid_0's multi_logloss: 1.52249
# [390]	valid_0's multi_logloss: 1.52243
# [391]	valid_0's multi_logloss: 1.52234
# [392]	valid_0's multi_logloss: 1.5223
# [393]	valid_0's multi_logloss: 1.52225
# [394]	valid_0's multi_logloss: 1.52221
# [395]	valid_0's multi_logloss: 1.52218
# [396]	valid_0's multi_logloss: 1.52216
# [397]	valid_0's multi_logloss: 1.52213
# [398]	valid_0's multi_logloss: 1.5221
# [399]	valid_0's multi_logloss: 1.52203
# [400]	valid_0's multi_logloss: 1.52198
# [401]	valid_0's multi_logloss: 1.52195
# [402]	valid_0's multi_logloss: 1.52191
# [403]	valid_0's multi_logloss: 1.52188
# [404]	valid_0's multi_logloss: 1.52181
# [405]	valid_0's multi_logloss: 1.52175
# [406]	valid_0's multi_logloss: 1.5217
# [407]	valid_0's multi_logloss: 1.52164
# [408]	valid_0's multi_logloss: 1.52158
# [409]	valid_0's multi_logloss: 1.52152
# [410]	valid_0's multi_logloss: 1.52151
# [411]	valid_0's multi_logloss: 1.52144
# [412]	valid_0's multi_logloss: 1.52139
# [413]	valid_0's multi_logloss: 1.52136
# [414]	valid_0's multi_logloss: 1.52134
# [415]	valid_0's multi_logloss: 1.5213
# [416]	valid_0's multi_logloss: 1.52124
# [417]	valid_0's multi_logloss: 1.52119
# [418]	valid_0's multi_logloss: 1.52115
# [419]	valid_0's multi_logloss: 1.52112
# [420]	valid_0's multi_logloss: 1.52107
# [421]	valid_0's multi_logloss: 1.52105
# [422]	valid_0's multi_logloss: 1.52098
# [423]	valid_0's multi_logloss: 1.52094
# [424]	valid_0's multi_logloss: 1.52093
# [425]	valid_0's multi_logloss: 1.52091
# [426]	valid_0's multi_logloss: 1.52088
# [427]	valid_0's multi_logloss: 1.52084
# [428]	valid_0's multi_logloss: 1.52079
# [429]	valid_0's multi_logloss: 1.52076
# [430]	valid_0's multi_logloss: 1.52074
# [431]	valid_0's multi_logloss: 1.5207
# [432]	valid_0's multi_logloss: 1.52067
# [433]	valid_0's multi_logloss: 1.52061
# [434]	valid_0's multi_logloss: 1.52055
# [435]	valid_0's multi_logloss: 1.52053
# [436]	valid_0's multi_logloss: 1.52048
# [437]	valid_0's multi_logloss: 1.52046
# [438]	valid_0's multi_logloss: 1.52045
# [439]	valid_0's multi_logloss: 1.52045
# [440]	valid_0's multi_logloss: 1.52042
# [441]	valid_0's multi_logloss: 1.52039
# [442]	valid_0's multi_logloss: 1.52039
# [443]	valid_0's multi_logloss: 1.52037
# [444]	valid_0's multi_logloss: 1.52032
# [445]	valid_0's multi_logloss: 1.52027
# [446]	valid_0's multi_logloss: 1.52026
# [447]	valid_0's multi_logloss: 1.52023
# [448]	valid_0's multi_logloss: 1.52022
# [449]	valid_0's multi_logloss: 1.52021
# [450]	valid_0's multi_logloss: 1.52017
# [451]	valid_0's multi_logloss: 1.52013
# [452]	valid_0's multi_logloss: 1.52011
# [453]	valid_0's multi_logloss: 1.52009
# [454]	valid_0's multi_logloss: 1.52006
# [455]	valid_0's multi_logloss: 1.52006
# [456]	valid_0's multi_logloss: 1.52001
# [457]	valid_0's multi_logloss: 1.51998
# [458]	valid_0's multi_logloss: 1.51995
# [459]	valid_0's multi_logloss: 1.51991
# [460]	valid_0's multi_logloss: 1.51987
# [461]	valid_0's multi_logloss: 1.51987
# [462]	valid_0's multi_logloss: 1.51987
# [463]	valid_0's multi_logloss: 1.51987
# [464]	valid_0's multi_logloss: 1.51985
# [465]	valid_0's multi_logloss: 1.51985
# [466]	valid_0's multi_logloss: 1.51983
# [467]	valid_0's multi_logloss: 1.51981
# [468]	valid_0's multi_logloss: 1.51979
# [469]	valid_0's multi_logloss: 1.51978
# [470]	valid_0's multi_logloss: 1.51976
# [471]	valid_0's multi_logloss: 1.51974
# [472]	valid_0's multi_logloss: 1.51971
# [473]	valid_0's multi_logloss: 1.5197
# [474]	valid_0's multi_logloss: 1.51966
# [475]	valid_0's multi_logloss: 1.51963
# [476]	valid_0's multi_logloss: 1.51963
# [477]	valid_0's multi_logloss: 1.51961
# [478]	valid_0's multi_logloss: 1.51962
# [479]	valid_0's multi_logloss: 1.5196
# [480]	valid_0's multi_logloss: 1.51959
# [481]	valid_0's multi_logloss: 1.51955
# [482]	valid_0's multi_logloss: 1.51952
# [483]	valid_0's multi_logloss: 1.51948
# [484]	valid_0's multi_logloss: 1.51948
# [485]	valid_0's multi_logloss: 1.51944
# [486]	valid_0's multi_logloss: 1.51942
# [487]	valid_0's multi_logloss: 1.5194
# [488]	valid_0's multi_logloss: 1.51939
# [489]	valid_0's multi_logloss: 1.51939
# [490]	valid_0's multi_logloss: 1.51939
# [491]	valid_0's multi_logloss: 1.51936
# [492]	valid_0's multi_logloss: 1.51935
# [493]	valid_0's multi_logloss: 1.51932
# [494]	valid_0's multi_logloss: 1.5193
# [495]	valid_0's multi_logloss: 1.5193
# [496]	valid_0's multi_logloss: 1.51929
# [497]	valid_0's multi_logloss: 1.51929
# [498]	valid_0's multi_logloss: 1.51931
# [499]	valid_0's multi_logloss: 1.5193
# [500]	valid_0's multi_logloss: 1.51929
# [501]	valid_0's multi_logloss: 1.51926
# [502]	valid_0's multi_logloss: 1.51925
# [503]	valid_0's multi_logloss: 1.51922
# [504]	valid_0's multi_logloss: 1.51921
# [505]	valid_0's multi_logloss: 1.51921
# [506]	valid_0's multi_logloss: 1.51919
# [507]	valid_0's multi_logloss: 1.51916
# [508]	valid_0's multi_logloss: 1.51913
# [509]	valid_0's multi_logloss: 1.51913
# [510]	valid_0's multi_logloss: 1.51913
# [511]	valid_0's multi_logloss: 1.51912
# [512]	valid_0's multi_logloss: 1.51908
# [513]	valid_0's multi_logloss: 1.51909
# [514]	valid_0's multi_logloss: 1.51906
# [515]	valid_0's multi_logloss: 1.51906
# [516]	valid_0's multi_logloss: 1.51904
# [517]	valid_0's multi_logloss: 1.51904
# [518]	valid_0's multi_logloss: 1.51902
# [519]	valid_0's multi_logloss: 1.519
# [520]	valid_0's multi_logloss: 1.51903
# [521]	valid_0's multi_logloss: 1.51902
# [522]	valid_0's multi_logloss: 1.51902
# [523]	valid_0's multi_logloss: 1.51899
# [524]	valid_0's multi_logloss: 1.51901
# [525]	valid_0's multi_logloss: 1.51901
# [526]	valid_0's multi_logloss: 1.51901
# [527]	valid_0's multi_logloss: 1.51902
# [528]	valid_0's multi_logloss: 1.51902
# [529]	valid_0's multi_logloss: 1.519
# [530]	valid_0's multi_logloss: 1.51898
# [531]	valid_0's multi_logloss: 1.51899
# [532]	valid_0's multi_logloss: 1.51899
# [533]	valid_0's multi_logloss: 1.51897
# [534]	valid_0's multi_logloss: 1.51896
# [535]	valid_0's multi_logloss: 1.51895
# [536]	valid_0's multi_logloss: 1.51893
# [537]	valid_0's multi_logloss: 1.51892
# [538]	valid_0's multi_logloss: 1.5189
# [539]	valid_0's multi_logloss: 1.51888
# [540]	valid_0's multi_logloss: 1.51887
# [541]	valid_0's multi_logloss: 1.51888
# [542]	valid_0's multi_logloss: 1.51885
# [543]	valid_0's multi_logloss: 1.51886
# [544]	valid_0's multi_logloss: 1.51885
# [545]	valid_0's multi_logloss: 1.51885
# [546]	valid_0's multi_logloss: 1.51883
# [547]	valid_0's multi_logloss: 1.51881
# [548]	valid_0's multi_logloss: 1.51883
# [549]	valid_0's multi_logloss: 1.51884
# [550]	valid_0's multi_logloss: 1.51887
# [551]	valid_0's multi_logloss: 1.51883
# [552]	valid_0's multi_logloss: 1.51883
# [553]	valid_0's multi_logloss: 1.51881
# [554]	valid_0's multi_logloss: 1.51881
# [555]	valid_0's multi_logloss: 1.51879
# [556]	valid_0's multi_logloss: 1.51876
# [557]	valid_0's multi_logloss: 1.51874
# [558]	valid_0's multi_logloss: 1.51874
# [559]	valid_0's multi_logloss: 1.51871
# [560]	valid_0's multi_logloss: 1.5187
# [561]	valid_0's multi_logloss: 1.51871
# [562]	valid_0's multi_logloss: 1.51871
# [563]	valid_0's multi_logloss: 1.51873
# [564]	valid_0's multi_logloss: 1.51873
# [565]	valid_0's multi_logloss: 1.51871
# [566]	valid_0's multi_logloss: 1.5187
# [567]	valid_0's multi_logloss: 1.51869
# [568]	valid_0's multi_logloss: 1.51868
# [569]	valid_0's multi_logloss: 1.5187
# [570]	valid_0's multi_logloss: 1.51871
# [571]	valid_0's multi_logloss: 1.51871
# [572]	valid_0's multi_logloss: 1.5187
# [573]	valid_0's multi_logloss: 1.51867
# [574]	valid_0's multi_logloss: 1.51866
# [575]	valid_0's multi_logloss: 1.51865
# [576]	valid_0's multi_logloss: 1.51865
# [577]	valid_0's multi_logloss: 1.51865
# [578]	valid_0's multi_logloss: 1.51862
# [579]	valid_0's multi_logloss: 1.51862
# [580]	valid_0's multi_logloss: 1.51861
# [581]	valid_0's multi_logloss: 1.51863
# [582]	valid_0's multi_logloss: 1.51865
# [583]	valid_0's multi_logloss: 1.51867
# [584]	valid_0's multi_logloss: 1.51869
# [585]	valid_0's multi_logloss: 1.51871
# [586]	valid_0's multi_logloss: 1.51869
# [587]	valid_0's multi_logloss: 1.51868
# [588]	valid_0's multi_logloss: 1.51866
# [589]	valid_0's multi_logloss: 1.51865
# [590]	valid_0's multi_logloss: 1.51865
# Early stopping, best iteration is:
# [580]	valid_0's multi_logloss: 1.51861
# FINISH train model and save model
# ===========================================================================

# %%
# 导入已保存模型
# gender_model = lgb_model(model_kind="gender")
# gender_model.load_model()
# age_model = lgb_model(model_kind="age")
# age_model.load_model()

# %%
print("START valid acc of predict")
# TODO 性别模型的预测
valid_gender_predict = gender_model.predict(valid_features)
valid_gender_predict = gender_model.transform_pred(valid_gender_predict)
acc_gender = accuracy_score(valid_gender_predict, valid_gender)

# TODO 年龄模型的预测
valid_age_predict = age_model.predict(valid_features)
valid_age_predict = age_model.transform_pred(valid_age_predict)
acc_age = accuracy_score(np.array(valid_age_predict), valid_age)

print("In valid data, accuracy of gender is {}, accuracy of age is {}".format(acc_gender, acc_age))
print("FINISH")
print("===========================================================================")
# Out:
# START valid acc of predict
# In valid data, accuracy of gender is 0.944060606060606, accuracy of age is 0.37607744107744107
# FINISH
# ===========================================================================

# %%
print("START loading test embedding")
test_np = np.loadtxt("embed/test/ag_test_embedding_800_1.csv", delimiter=", ")
test_np[test_np == 0] = np.nan

tc_test_age = pd.read_csv("tc/test_target_age.csv")
tc_test_gender = pd.read_csv("tc/test_target_gender.csv")
print("===========================================================================")
# Out:
# START loading train embedding and train user info
# ===========================================================================

# %%
test_uid = test_np[:, 0].astype(int)
test_features = test_np[:, 1:]

test_features_gender = np.concatenate([test_features, tc_test_gender.values[:, 1:]], axis=1)
test_features_age = np.concatenate([test_features, tc_test_age.values[:, 1:]], axis=1)

# %%
print("START test predict")

# TODO 性别模型的预测
test_gender_predict = gender_model.predict(test_features_gender)
test_gender_predict = gender_model.transform_pred(test_gender_predict)
# TODO 年龄模型的预测
test_age_predict = age_model.predict(test_features_age)
test_age_predict = age_model.transform_pred(test_age_predict)

result = pd.DataFrame({"user_id": test_uid, "predicted_age": test_age_predict, "predicted_gender": test_gender_predict})
result.loc[:, "predicted_age"] += 1
result.loc[:, "predicted_gender"] += 1
result.to_csv("results_complex.csv", index=False)

print("FINISH ALL and save result to results.csv")
print("===========================================================================")

# %%
train_ad, train_click, train_user, test_ad, test_click = data.load_data()
# train_record
train_record = pd.merge(train_click, train_ad, on="creative_id")
# test_record
test_record = pd.merge(test_click, test_ad, on="creative_id")

# %%
grouped = test_record.groupby("user_id")

# %%
test_np = np.loadtxt("embed/test/test_embedding_all_1.csv", delimiter=", ")

# %%
for user_id, record in grouped:
    print(user_id)
    print(record)
    break
